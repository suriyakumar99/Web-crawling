# %% [markdown]
# EXTRACTION OF HTML CODE

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
html=urlopen("https://en.wikipedia.org/wiki/Main_Page")
bs1=bs(html, "html.parser")
print(bs1)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %% [markdown]
# EXTRACTION OF COMPONENTS AND HTML PARSING

# %%
titleAll= bs1.findAll('h3')
titleList=[] 
for title in titleAll:
    titleList.append(title.get_text())
    print(title.get_text())
# Out:
# Personal tools
#
# Namespaces
#
# Variants
#
# Views
#
# More
#
#
# Search
#
# Navigation
#
# Contribute
#
# Tools
#
# Print/export
#
# In other projects
#
# Languages

# %%
for child in bs1.find('table',{'id':'mp-upper'}).children:
    print(child)
# Out:
# <tbody><tr>
# <td class="MainPageBG mp-bordered" id="mp-left">
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# ...

# %%
bs1.find_all(lambda tag: len(tag.attrs) == 5)
# Out:
# [<a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/" hreflang="ar" lang="ar" title="Arabic">العربية</a>,
#  <a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/" hreflang="bn" lang="bn" title="Bangla">বাংলা</a>,
#  <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/" hreflang="bg" lang="bg" title="Bulgarian">Български</a>,
#  <a class="interlanguage-link-target" href="https://bs.wikipedia.org/wiki/" hreflang="bs" lang="bs" title="Bosnian">Bosanski</a>,
#  <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/" hreflang="ca" lang="ca" title="Catalan">Català</a>,
#  <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/" hreflang="cs" lang="cs" title="Czech">Čeština</a>,
#  <a class="interlanguage-link-target" href="https://da.wikipedia.org/wiki/" hreflang="da" lang="da" title="Danish">Dansk</a>,
# ...

# %% [markdown]
# CLASSIFYING TITLE INTO DF

# %%
import pandas as pd

df= pd.DataFrame(titleList)
print(df)
# Out:
#                       0
# 0      Personal tools\n
# 1          Namespaces\n
# 2            Variants\n
# 3               Views\n
# 4                More\n
# 5            \nSearch\n
# 6          Navigation\n
# 7          Contribute\n
# 8               Tools\n
# 9        Print/export\n
# 10  In other projects\n
# 11          Languages\n

# %% [markdown]
# ERROR HANDLING

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup


def getTitle(url):
    try:
        html = urlopen(url)
    except HTTPError as e:
        return None
    try:
        bsObj = BeautifulSoup(html.read(), "lxml")
        title = bsObj.body.h1
    except AttributeError as e:
        return None
    return title

title = getTitle("https://en.wikipedia.org/wiki/Main_Page")
if title == None:
    print("Title not found")
else:
    print(title)
# Out:
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
